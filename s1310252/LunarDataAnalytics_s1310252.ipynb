# %% [markdown]
# # Installing Necessary Ubuntu packages

# %%
# Installing necessary modules
# !apt update
# !apt install -y nco cdo gdal-bin
# !which ncrename
# !which cdo
# !which gdal_translate
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 34 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cdo is already the newest version (2.0.4-1).
# nco is already the newest version (5.0.6-1).
# gdal-bin is already the newest version (3.8.4+dfsg-1~jammy0).
# 0 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# /usr/bin/ncrename
# /usr/bin/cdo
# /usr/bin/gdal_translate

# %% [markdown]
# # Installing geoAnalytics package

# %%
# !pip install -U geoanalytics
# Out:
# Collecting geoanalytics
#   Downloading geoanalytics-2025.6.12.3-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (5.9.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (3.10.0)
# Collecting resource (from geoanalytics)
#   Downloading Resource-0.2.1-py2.py3-none-any.whl.metadata (478 bytes)
# Collecting validators (from geoanalytics)
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (2.4.0)
# Collecting psycopg2-binary (from geoanalytics)
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: shapely in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (2.1.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (4.67.1)
# Collecting mplcursors (from geoanalytics)
#   Downloading mplcursors-0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (1.6.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (5.24.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (11.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (2.0.2)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (8.2.3)
# Collecting sphinx-rtd-theme (from geoanalytics)
#   Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting discord.py (from geoanalytics)
#   Downloading discord_py-2.5.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (3.5)
# Collecting deprecated (from geoanalytics)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting fastparquet (from geoanalytics)
#   Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.11/dist-packages (from geoanalytics) (0.60.0)
# Collecting pami (from geoanalytics)
#   Downloading pami-2025.3.25.1-py3-none-any.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 3.1 MB/s eta 0:00:00
# Collecting rasterio (from geoanalytics)
#   Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->geoanalytics) (1.17.2)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from discord.py->geoanalytics) (3.11.15)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.11/dist-packages (from fastparquet->geoanalytics) (2.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet->geoanalytics) (2025.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastparquet->geoanalytics) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->geoanalytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->geoanalytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->geoanalytics) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geoanalytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geoanalytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geoanalytics) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geoanalytics) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->geoanalytics) (3.2.3)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba->geoanalytics) (0.43.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->geoanalytics) (9.1.2)
# Collecting affine (from rasterio->geoanalytics)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from rasterio->geoanalytics) (25.3.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from rasterio->geoanalytics) (2025.4.26)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.11/dist-packages (from rasterio->geoanalytics) (8.2.1)
# Collecting cligj>=0.5 (from rasterio->geoanalytics)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->geoanalytics)
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl.metadata (6.4 kB)
# Collecting JsonForm>=0.0.2 (from resource->geoanalytics)
#   Downloading JsonForm-0.0.2.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting JsonSir>=0.0.2 (from resource->geoanalytics)
#   Downloading JsonSir-0.0.2.tar.gz (2.2 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-easyconfig>=0.1.0 (from resource->geoanalytics)
#   Downloading Python_EasyConfig-0.1.7-py2.py3-none-any.whl.metadata (462 bytes)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->geoanalytics) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->geoanalytics) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn->geoanalytics) (3.6.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (2.19.1)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (2.32.3)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx->geoanalytics) (3.1.0)
# Collecting sphinxcontrib-jquery<5,>=4 (from sphinx-rtd-theme->geoanalytics)
#   Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->geoanalytics) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->geoanalytics) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->geoanalytics) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->geoanalytics) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->geoanalytics) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->geoanalytics) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx->geoanalytics) (3.0.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from JsonForm>=0.0.2->resource->geoanalytics) (4.24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->geoanalytics) (1.17.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from python-easyconfig>=0.1.0->resource->geoanalytics) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->geoanalytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->geoanalytics) (3.10)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->geoanalytics) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->geoanalytics) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->geoanalytics) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema->JsonForm>=0.0.2->resource->geoanalytics) (4.14.0)
# Downloading geoanalytics-2025.6.12.3-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.4/131.4 kB 6.1 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading discord_py-2.5.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.2 MB/s eta 0:00:00
# Downloading fastparquet-2024.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 60.7 MB/s eta 0:00:00
# Downloading mplcursors-0.6-py3-none-any.whl (20 kB)
# Downloading pami-2025.3.25.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.5 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 96.3 MB/s eta 0:00:00
# Downloading rasterio-1.4.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 91.0 MB/s eta 0:00:00
# Downloading Resource-0.2.1-py2.py3-none-any.whl (25 kB)
# Downloading sphinx_rtd_theme-3.0.2-py2.py3-none-any.whl (7.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 104.0 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 4.8 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading Python_EasyConfig-0.1.7-py2.py3-none-any.whl (5.4 kB)
# Downloading sphinxcontrib_jquery-4.1-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 kB 14.2 MB/s eta 0:00:00
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Building wheels for collected packages: JsonForm, JsonSir
#   Building wheel for JsonForm (setup.py) ... done
#   Created wheel for JsonForm: filename=JsonForm-0.0.2-py3-none-any.whl size=3311 sha256=63ee3fb6d6b525a6bd35175cec58d09a60e9c7801f3dd3deb3114ed51c2c3ab3
#   Stored in directory: /root/.cache/pip/wheels/ee/53/ac/c77344bd941889aa16ad694cb203ee587de1749e973ba9fdb8
#   Building wheel for JsonSir (setup.py) ... done
#   Created wheel for JsonSir: filename=JsonSir-0.0.2-py3-none-any.whl size=4754 sha256=3a91962ed80bcbe0f43a60820aa38845c7ad5c7adf3e908d270107cf540804a0
#   Stored in directory: /root/.cache/pip/wheels/d0/92/1d/bdf54bd7aefaf8305526450e3337733509b755328692619664
# Successfully built JsonForm JsonSir
# Installing collected packages: JsonSir, validators, python-easyconfig, psycopg2-binary, deprecated, cligj, click-plugins, affine, rasterio, sphinxcontrib-jquery, mplcursors, fastparquet, discord.py, sphinx-rtd-theme, JsonForm, resource, pami, geoanalytics
# Successfully installed JsonForm-0.0.2 JsonSir-0.0.2 affine-2.4.0 click-plugins-1.1.1 cligj-0.7.2 deprecated-1.2.18 discord.py-2.5.2 fastparquet-2024.11.0 geoanalytics-2025.6.12.3 mplcursors-0.6 pami-2025.3.25.1 psycopg2-binary-2.9.10 python-easyconfig-0.1.7 rasterio-1.4.3 resource-0.2.1 sphinx-rtd-theme-3.0.2 sphinxcontrib-jquery-4.1 validators-0.35.0

# %% [markdown]
# # Knowing the information of geoAnalytics package

# %%
pip show geoanalytics
# Out:
# Name: geoanalytics
# Version: 2025.6.12.3
# Summary: This software is being developed at the University of Aizu, Aizu-Wakamatsu, Fukushima, Japan
# Home-page: https://github.com/UdayLab/geoanalytics
# Author:
# Author-email: Rage Uday Kiran <uday.rage@gmail.com>
# License: GPLv3
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: deprecated, discord.py, fastparquet, matplotlib, mplcursors, networkx, numba, numpy, pami, pandas, Pillow, plotly, psutil, psycopg2-binary, rasterio, resource, scikit-learn, shapely, sphinx, sphinx-rtd-theme, tqdm, urllib3, validators
# Required-by:

# %% [markdown]
# ## Download any dataset with extension of both .img and .lbl from the below link

# %% [markdown]
# Link --> https://data.darts.isas.jaxa.jp/pub/pds3/sln-l-mi-5-map-v3.0/
#
# Example Direction : --> https://data.darts.isas.jaxa.jp/pub/pds3/sln-l-mi-5-map-v3.0/lon035/data/

# %% [markdown]
# ## Use !wget command to download the `.img` and `.lbl` files

# %%
# Download any files by using the wget command
# !wget https://data.darts.isas.jaxa.jp/pub/pds3/sln-l-mi-5-map-v3.0/lon035/data/MI_MAP_03_S16E035S17E036SC.img
# Out:
# --2025-06-12 06:40:39--  https://data.darts.isas.jaxa.jp/pub/pds3/sln-l-mi-5-map-v3.0/lon035/data/MI_MAP_03_S16E035S17E036SC.img
# Resolving data.darts.isas.jaxa.jp (data.darts.isas.jaxa.jp)... 159.60.133.108
# Connecting to data.darts.isas.jaxa.jp (data.darts.isas.jaxa.jp)|159.60.133.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 92274688 (88M) [application/octet-stream]
# Saving to: ‘MI_MAP_03_S16E035S17E036SC.img.1’
#
# MI_MAP_03_S16E035S1 100%[===================>]  88.00M  48.1KB/s    in 21m 6s
#
# 2025-06-12 07:01:57 (71.2 KB/s) - ‘MI_MAP_03_S16E035S17E036SC.img.1’ saved [92274688/92274688]

# %%
# !wget https://data.darts.isas.jaxa.jp/pub/pds3/sln-l-mi-5-map-v3.0/lon035/data/MI_MAP_03_S16E035S17E036SC.lbl
# Out:
# --2025-06-12 07:01:57--  https://data.darts.isas.jaxa.jp/pub/pds3/sln-l-mi-5-map-v3.0/lon035/data/MI_MAP_03_S16E035S17E036SC.lbl
# Resolving data.darts.isas.jaxa.jp (data.darts.isas.jaxa.jp)... 159.60.133.108
# Connecting to data.darts.isas.jaxa.jp (data.darts.isas.jaxa.jp)|159.60.133.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12155 (12K)
# Saving to: ‘MI_MAP_03_S16E035S17E036SC.lbl’
#
# MI_MAP_03_S16E035S1 100%[===================>]  11.87K  67.1KB/s    in 0.2s
#
# 2025-06-12 07:02:00 (67.1 KB/s) - ‘MI_MAP_03_S16E035S17E036SC.lbl’ saved [12155/12155]

# %% [markdown]
# # **Operatioin 1: Raster to CSV**

# %% [markdown]
# ## ***Step1: Import RasterToTSV package from geoAnalytics.conversion***

# %%
# Import Raster To TSV package
from geoanalytics.conversion import Raster2CSV

# %% [markdown]
# ## ***Step2: Pass the lbl file as input and give desired outputFile name also specify the inputband value as well as ouput band value***

# %%
# Specify startBand = 1
# Specify endBand = 9
converter = Raster2CSV.Raster2CSV(inputFile='MI_MAP_03_S16E035S17E036SC.lbl', outputFile='Moon.csv', startBand=1, endBand=9)

# %% [markdown]
# ## ***Step3: Conver the raster file into a CSV file***

# %%
# convert using run() method
converter.run()
# Out:
# Processing: MI_MAP_03_S16E035S17E036SC.lbl
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-4196709657> in <cell line: 0>()
#       1 # convert using run() method
# ----> 2 converter.run()
#
# /usr/local/lib/python3.11/dist-packages/geoanalytics/conversion/Raster2CSV.py in run(self)
#      97
#      98         print(f"Processing: {self.inputFile}")
# ---> 99         raster2tsv.raster2tsv(params)  # class call with CLI-style string
#     100
#     101         df = pd.read_csv(self.outputFile, header=None, sep='\t')
#
# /usr/local/lib/python3.11/dist-packages/geoanalytics/conversion/raster2tsv.py in __init__(self, parameter)
#     143             for band in bands:
#     144                 band_data = band.ReadAsArray(srcwin[0], y, srcwin[2], 1)
# --> 145                 band_data = Numeric.reshape(band_data, (srcwin[2],))
#     146                 data.append(band_data)
#     147
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
# ---> 54         return _wrapit(obj, method, *args, **kwds)
#      55
#      56     try:
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      44     # but this follows what was done before. TODO: revisit this.
#      45     arr, = conv.as_arrays(subok=False)
# ---> 46     result = getattr(arr, method)(*args, **kwds)
#      47
#      48     return conv.wrap(result, to_scalar=False)
#
# ValueError: cannot reshape array of size 1 into shape (2048,)

# %% [markdown]
# # **Operation 2 : Clustering the Data**

# %% [markdown]
# ## ***Step 1: Read the obtained CSV into a dataframe***

# %%
# import pandas
import pandas as pd
# read the dataframe with separator as "tab" space
df = pd.read_csv('Moon.csv', sep='\t')
# show the dataframe
df
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-16-2752483494> in <cell line: 0>()
#       2 import pandas as pd
#       3 # read the dataframe with separator as "tab" space
# ----> 4 df = pd.read_csv('Moon.csv', sep='\t')
#       5 # show the dataframe
#       6 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1896
#    1897         try:
# -> 1898             return mapping[engine](f, **self.options)
#    1899         except Exception:
#    1900             if self.handles is not None:
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      91             # Fail here loudly instead of in cython after reading
#      92             import_optional_dependency("pyarrow")
# ---> 93         self._reader = parsers.TextReader(src, **kwds)
#      94
#      95         self.unnamed_cols = self._reader.unnamed_cols
#
# parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# EmptyDataError: No columns to parse from file

# %% [markdown]
# ## ***Step2: Import any clustering algorithm from geoanalytics.clustering***

# %%
# Import the Gaussianmixture algorithm
from geoanalytics.clustering import Gaussianmixture
# Pass the dataframe into the clustering algorithm
obj = Gaussianmixture.Gaussianmixture(dataframe=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-1520632310> in <cell line: 0>()
#       2 from geoanalytics.clustering import Gaussianmixture
#       3 # Pass the dataframe into the clustering algorithm
# ----> 4 obj = Gaussianmixture.Gaussianmixture(dataframe=df)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## ***Step3: Execute the run() method to cluster the data***

# %% [markdown]
# ### ***Also specify the parameters such as `n_components`, `max_iters` and `random_state` etc,.***

# %%
# Assign "labels", "weights" and "means" as output variable names. Since our algorithm is going to return three components respectively
labels, weights, means = obj.run(n_components=4, max_iters=100, covariance_type="full", init_params='kmeans', random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-459130064> in <cell line: 0>()
#       1 # Assign "labels", "weights" and "means" as output variable names. Since our algorithm is going to return three components respectively
# ----> 2 labels, weights, means = obj.run(n_components=4, max_iters=100, covariance_type="full", init_params='kmeans', random_state=0)
#
# NameError: name 'obj' is not defined

# %% [markdown]
# ## ***Step4: Print the labels***

# %%
labels

# %% [markdown]
# ## ***Step5: Print the weights***

# %%
weights

# %% [markdown]
# ## ***Step6: Print the means***

# %%
means

# %% [markdown]
# ## ***Step7: To know the run time and memory consumption of Algorithm, print the statistical values***

# %%
# Get the run time
obj.getRuntime()
# Get the Memory in RSS
obj.getMemoryRSS()
# Get the memory in USS
obj.getMemoryUSS()

# %% [markdown]
# ## ***Step8: Save the labels, weights and means***

# %%
# Specify the output names for labels, weights and Means respectively
obj.save(outputFileLabels='GaussianMixtureLabels.csv', outputFileWeights='GaussianMixtureWeights.csv', outputFileMeans='GaussianMixtureMeans.csv')

# %% [markdown]
# # **Operation3: CSV to Raster**

# %% [markdown]
# ## ***Step1: Import CSV2Raster from geoanalytics.conversion***

# %%
from geoanalytics.conversion import CSV2Raster as CSV2Raster

# %% [markdown]
# ## ***Step2: Pass the dataFrame and give desired outputFile name***

# %%
# Pass the labels as a dataframe
process = CSV2Raster.CSV2Raster(dataframe=labels,outputFile='GaussianMixture.tiff')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-638281988> in <cell line: 0>()
#       1 # Pass the labels as a dataframe
# ----> 2 process = CSV2Raster.CSV2Raster(dataframe=labels,outputFile='GaussianMixture.tiff')
#
# NameError: name 'labels' is not defined

# %% [markdown]
# ## **Step3: Execute the run() method**

# %%
process.run()

# %% [markdown]
# # **Operation 4: Visualization**

# %% [markdown]
# ## ***Step1: Import TiffViewer from geoanalytics.visualization***

# %%
# Import the TiffViewer module
from geoanalytics.visualization import TiffViewer

# %% [markdown]
# ## ***Step2: Input the RasterFile or pass it into the parameter***

# %%
viewer = TiffViewer.TiffViewer(inputFile='GaussianMixture.tiff')

# %% [markdown]
# ## ***Step3: Display the image with desired scaling map***

# %% [markdown]
# ##### ***1. gray scale***

# %%
# Specify  the cmap --> "gray" & title --> (Optional)
viewer.run(cmap='gray', title='TIFF Image')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_base.pyx in rasterio._base.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: GaussianMixture.tiff: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-20-4027484008> in <cell line: 0>()
#       1 # Specify  the cmap --> "gray" & title --> (Optional)
# ----> 2 viewer.run(cmap='gray', title='TIFF Image')
#
# /usr/local/lib/python3.11/dist-packages/geoanalytics/visualization/TiffViewer.py in run(self, cmap, title)
#      26
#      27     def run(self, cmap='gray', title='TIFF Image'):
# ---> 28         with rasterio.open(self.inputFile) as src:
#      29             self.imageData = src.read(1)
#      30         if self.imageData is None:
#
# /usr/local/lib/python3.11/dist-packages/rasterio/env.py in wrapper(*args, **kwds)
#     461
#     462         with env_ctor(session=session):
# --> 463             return f(*args, **kwds)
#     464
#     465     return wrapper
#
# /usr/local/lib/python3.11/dist-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     354
#     355             if mode == "r":
# --> 356                 dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357             elif mode == "r+":
#     358                 dataset = get_writer_for_path(path, driver=driver)(
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: GaussianMixture.tiff: No such file or directory

# %% [markdown]
# ##### ***2. Jet Scale***

# %%
# Specify  the cmap --> "jet" & title --> (Optional)
viewer.run(cmap='jet', title='TIFF Image')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_base.pyx in rasterio._base.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: GaussianMixture.tiff: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-21-3132353198> in <cell line: 0>()
#       1 # Specify  the cmap --> "jet" & title --> (Optional)
# ----> 2 viewer.run(cmap='jet', title='TIFF Image')
#
# /usr/local/lib/python3.11/dist-packages/geoanalytics/visualization/TiffViewer.py in run(self, cmap, title)
#      26
#      27     def run(self, cmap='gray', title='TIFF Image'):
# ---> 28         with rasterio.open(self.inputFile) as src:
#      29             self.imageData = src.read(1)
#      30         if self.imageData is None:
#
# /usr/local/lib/python3.11/dist-packages/rasterio/env.py in wrapper(*args, **kwds)
#     461
#     462         with env_ctor(session=session):
# --> 463             return f(*args, **kwds)
#     464
#     465     return wrapper
#
# /usr/local/lib/python3.11/dist-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, opener, **kwargs)
#     354
#     355             if mode == "r":
# --> 356                 dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     357             elif mode == "r+":
#     358                 dataset = get_writer_for_path(path, driver=driver)(
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: GaussianMixture.tiff: No such file or directory

# %% [markdown]
# # **Operation 4: Pattern Mining**

# %% [markdown]
# ## ***Step1: Converting Raster Dataframe into a Database***

# %%
# Install PAMI library for Pattern Mining
# !pip install PAMI
# Out:
# Requirement already satisfied: PAMI in /usr/local/lib/python3.11/dist-packages (2025.3.25.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from PAMI) (5.9.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from PAMI) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from PAMI) (5.24.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from PAMI) (3.10.0)
# Requirement already satisfied: resource in /usr/local/lib/python3.11/dist-packages (from PAMI) (0.2.1)
# Requirement already satisfied: validators in /usr/local/lib/python3.11/dist-packages (from PAMI) (0.35.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from PAMI) (2.4.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from PAMI) (11.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from PAMI) (2.0.2)
# Requirement already satisfied: sphinx in /usr/local/lib/python3.11/dist-packages (from PAMI) (8.2.3)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.11/dist-packages (from PAMI) (3.0.2)
# Requirement already satisfied: discord.py in /usr/local/lib/python3.11/dist-packages (from PAMI) (2.5.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from PAMI) (3.5)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from PAMI) (1.2.18)
# Requirement already satisfied: fastparquet in /usr/local/lib/python3.11/dist-packages (from PAMI) (2024.11.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->PAMI) (1.17.2)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /usr/local/lib/python3.11/dist-packages (from discord.py->PAMI) (3.11.15)
# Requirement already satisfied: cramjam>=2.3 in /usr/local/lib/python3.11/dist-packages (from fastparquet->PAMI) (2.10.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from fastparquet->PAMI) (2025.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from fastparquet->PAMI) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->PAMI) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->PAMI) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->PAMI) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->PAMI) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->PAMI) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->PAMI) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->PAMI) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->PAMI) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->PAMI) (9.1.2)
# Requirement already satisfied: JsonForm>=0.0.2 in /usr/local/lib/python3.11/dist-packages (from resource->PAMI) (0.0.2)
# Requirement already satisfied: JsonSir>=0.0.2 in /usr/local/lib/python3.11/dist-packages (from resource->PAMI) (0.0.2)
# Requirement already satisfied: python-easyconfig>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from resource->PAMI) (0.1.7)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (3.1.6)
# Requirement already satisfied: Pygments>=2.17 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (2.19.1)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (3.0.1)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (2.17.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (1.4.1)
# Requirement already satisfied: requests>=2.30.0 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (2.32.3)
# Requirement already satisfied: roman-numerals-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from sphinx->PAMI) (3.1.0)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.11/dist-packages (from sphinx-rtd-theme->PAMI) (4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->PAMI) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->PAMI) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->PAMI) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->PAMI) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->PAMI) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->PAMI) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4,>=3.7.4->discord.py->PAMI) (1.20.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2>=3.1->sphinx->PAMI) (3.0.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/dist-packages (from JsonForm>=0.0.2->resource->PAMI) (4.24.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->PAMI) (1.17.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from python-easyconfig>=0.1.0->resource->PAMI) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->PAMI) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->PAMI) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.30.0->sphinx->PAMI) (2025.4.26)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->PAMI) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->PAMI) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema->JsonForm>=0.0.2->resource->PAMI) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from referencing>=0.28.4->jsonschema->JsonForm>=0.0.2->resource->PAMI) (4.14.0)

# %% [markdown]
# #### ***Reducing the size of our dataframe***
# #### ***Because it will consume a lot of time and memory***

# %%
# Select only the first 1000 pixels in the Raster File
df = df.iloc[:1000,:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2101610808> in <cell line: 0>()
#       1 # Select only the first 1000 pixels in the Raster File
# ----> 2 df = df.iloc[:1000,:]
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### ***Step 1.1: Import RasterDF2DB from geoanalytics.conversion***

# %%
from geoanalytics.conversion import RasterDF2DB

# %%
# Pass the dataframe as input dataframe
obj = RasterDF2DB.RasterDF2DB(dataframe=df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2321239427> in <cell line: 0>()
#       1 # Pass the dataframe as input dataframe
# ----> 2 obj = RasterDF2DB.RasterDF2DB(dataframe=df)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### ***Step 1.2: Prepare the Transactional Dataframe***

# %%
obj.prepareTransactionalDataframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-1291411799> in <cell line: 0>()
# ----> 1 obj.prepareTransactionalDataframe()
#
# NameError: name 'obj' is not defined

# %% [markdown]
# ### ***Step 1.3: Give the desired output  `DBname` and `condition` along with `thresholdValue`***

# %%
# Select the pixels which has their band value more than or equal to 4000
obj.convertToTransactionalDB(DBname='transactionalDB.csv', condition='>=', thresholdValue=4000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-2229972116> in <cell line: 0>()
#       1 # Select the pixels which has their band value more than or equal to 4000
# ----> 2 obj.convertToTransactionalDB(DBname='transactionalDB.csv', condition='>=', thresholdValue=4000)
#
# NameError: name 'obj' is not defined

# %% [markdown]
# ##### **Print the head of the Transactional Database**

# %%
# !head transactionalDB.csv
# Out:
# head: cannot open 'transactionalDB.csv' for reading: No such file or directory

# %% [markdown]
# ## ***Step 2: Import the FrequentPatternMining from `geoanalytics.patternmining`***

# %%
from geoanalytics.patternMining import FrequentPatternMining

# %% [markdown]
# ## ***Step 3: Pass the `inputFile` into the algorithm***

# %%
alg = FrequentPatternMining.FrequentPatternMining(inputFile='transactionalDB.csv')

# %% [markdown]
# ## ***Step 4: Show the database statistics to know the appropriate parameters to mine the patterns***

# %%
# Get to know the database statistics and visualization of frequency and transaction length graphs
alg.showDBstats()
# Out:
# File Not Found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/PAMI/extras/dbStats/TransactionalDatabase.py in readDatabase(self)
#     148                 try:
# --> 149                     with open(self.inputFile, 'r', encoding='utf-8') as f:
#     150                         for line in f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'transactionalDB.csv'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-2248229952> in <cell line: 0>()
#       1 # Get to know the database statistics and visualization of frequency and transaction length graphs
# ----> 2 alg.showDBstats()
#
# /usr/local/lib/python3.11/dist-packages/geoanalytics/patternMining/FrequentPatternMining.py in showDBstats(self)
#      28     def showDBstats(self):
#      29         obj = TransactionalDatabase(self.inputFile)
# ---> 30         obj.run()
#      31         obj.printStats()
#      32         obj.plotGraphs()
#
# /usr/local/lib/python3.11/dist-packages/PAMI/extras/dbStats/TransactionalDatabase.py in run(self)
#     119
#     120     def run(self) -> None:
# --> 121         self.readDatabase()
#     122
#     123     def readDatabase(self) -> None:
#
# /usr/local/lib/python3.11/dist-packages/PAMI/extras/dbStats/TransactionalDatabase.py in readDatabase(self)
#     156                 except IOError:
#     157                     print("File Not Found")
# --> 158                     quit()
#     159         self.lengthList = [len(s) for s in self.database.values()]
#     160
#
# NameError: name 'quit' is not defined

# %% [markdown]
# ## ***Step 5: Specify the parameter `minSupport` to mine the patterns in database***

# %%
# More Minimum Support --> less Patterns
# Less Minimum Support --> More Patterns
alg.run(minSupport=8)
# Out:
# File Not Found
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/PAMI/frequentPattern/basic/FPGrowth.py in __creatingItemSets(self)
#     243                 try:
# --> 244                     with open(self._iFile, 'r', encoding='utf-8') as f:
#     245                         for line in f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'transactionalDB.csv'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-3400864958> in <cell line: 0>()
#       1 # More Minimum Support --> less Patterns
#       2 # Less Minimum Support --> More Patterns
# ----> 3 alg.run(minSupport=8)
#
# /usr/local/lib/python3.11/dist-packages/geoanalytics/patternMining/FrequentPatternMining.py in run(self, minSupport)
#      34     def run(self, minSupport=8):
#      35         self.miner = FPGrowth.FPGrowth(self.inputFile, minSupport)
# ---> 36         self.miner.startMine()
#      37         self.miner.printResults()
#      38
#
# /usr/local/lib/python3.11/dist-packages/deprecated/classic.py in wrapper_function(wrapped_, instance_, args_, kwargs_)
#     197                 else:
#     198                     warnings.warn(msg, category=self.category, stacklevel=stacklevel)
# --> 199                 return wrapped_(*args_, **kwargs_)
#     200
#     201             return wrapper_function(wrapped)
#
# /usr/local/lib/python3.11/dist-packages/PAMI/frequentPattern/basic/FPGrowth.py in startMine(self)
#     435         Starting the mining process
#     436         """
# --> 437         self.mine()
#     438
#     439     def getMemoryUSS(self) -> float:
#
# /usr/local/lib/python3.11/dist-packages/PAMI/frequentPattern/basic/FPGrowth.py in mine(self)
#     411         if self._minSup is None:
#     412             raise Exception("Please enter the Minimum Support")
# --> 413         self.__creatingItemSets()
#     414         self._minSup = self.__convert(self._minSup)
#     415         _minSup = self._minSup
#
# /usr/local/lib/python3.11/dist-packages/PAMI/frequentPattern/basic/FPGrowth.py in __creatingItemSets(self)
#     250                 except IOError:
#     251                     print("File Not Found")
# --> 252                     quit()
#     253
#     254     def __convert(self, value) -> float:
#
# NameError: name 'quit' is not defined

# %% [markdown]
# ## ***Step 6: Save the patterns***

# %%
alg.save(outputFile='FrequentPatterns.txt')
# Out:
# Frequent patterns saved to: FrequentPatterns.txt

# %% [markdown]
# #### **View the saved frequent patterns**

# %%
# !head FrequentPatterns.txt
# Out:
# head: cannot open 'FrequentPatterns.txt' for reading: No such file or directory
